# %%
import pandas as pd
import numpy as np

home_value_df = pd.read_csv('Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
home_value_forecast_df = pd.read_csv('Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
adidas_sale_df = pd.read_excel('Adidas US Sales Datasets.xlsx', index_col=0 ,header=4)

# %%
home_value_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Columns: 294 entries, RegionID to 2024-01-31
# dtypes: float64(289), int64(2), object(3)
# memory usage: 2.0+ MB

# %%
home_value_forecast_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName    BaseDate  \
# 0    102001         0    United States    country       NaN  2024-01-31
# 1    394913         1     New York, NY        msa        NY  2024-01-31
# 2    753899         2  Los Angeles, CA        msa        CA  2024-01-31
# 3    394463         3      Chicago, IL        msa        IL  2024-01-31
# 4    394514         4       Dallas, TX        msa        TX  2024-01-31
#
#    2024-02-29  2024-04-30  2025-01-31
# 0         0.2         1.0         4.2
# 1         0.4         1.1         2.2
# 2        -0.4        -1.3         1.9
# 3         0.4         1.6         3.1
# 4         0.1         1.0         4.4

# %%
adidas_sale_df.head(20)
# Out:
#         Retailer  Retailer ID Invoice Date     Region     State      City  \
# NaN  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-06  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-07  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-08  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-21  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-22  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-23  Northeast  New York  New York
# NaN  Foot Locker      1185732   2020-01-24  Northeast  New York  New York
# ...
